# %% [markdown]
# <a href="https://colab.research.google.com/github/hy-e/2025-ai-expert/blob/main/%EC%95%8C%EA%B3%A0%EB%A6%AC%EC%A6%98/%EC%84%9C%ED%99%8D%EC%84%9D%20%EA%B5%90%EC%88%98%EB%8B%98/VQA_with_quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Code walkthrough of the pytorch implementation of the paper VQA: Visual Question Answering(ICCV 2015)
#
# ![](assets/transformer1.png)

# %% [markdown]
# ##Import Libraries

# %%
import os
import argparse
from PIL import Image
import numpy as np
import json
import re
from collections import defaultdict
import torch
import torch.nn as nn
import torchvision.models as models
import torch.utils.data as data
import torchvision.transforms as transforms
import torch.optim as optim
import tqdm
import easydict
from torch.optim import lr_scheduler
import gc
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare Data

# %%
#Make Folders
######################################################################
DATASETS_DIR = "./datasets"

ANNOTATIONS_DIR = os.path.join(DATASETS_DIR,'Annotations')
QUESTIONS_DIR = os.path.join(DATASETS_DIR,'Questions')
IMAGES_DIR = os.path.join(DATASETS_DIR,'Images')

# !mkdir $DATASETS_DIR
# !mkdir $ANNOTATIONS_DIR
# !mkdir $QUESTIONS_DIR
# !mkdir $IMAGES_DIR
######################################################################

# Download datasets from VQA official url: https://visualqa.org/download.html

#VQA Annotations
# !wget -O $ANNOTATIONS_DIR/v2_Annotations_Train_mscoco.zip "https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Train_mscoco.zip"
# !wget -O $ANNOTATIONS_DIR/v2_Annotations_Val_mscoco.zip "https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Annotations_Val_mscoco.zip"

# VQA Input Questions
# !wget -O $QUESTIONS_DIR/v2_Questions_Train_mscoco.zip "https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Train_mscoco.zip"
# !wget -O $QUESTIONS_DIR/v2_Questions_Val_mscoco.zip "https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Val_mscoco.zip"
# !wget -O $QUESTIONS_DIR/v2_Questions_Test_mscoco.zip "https://s3.amazonaws.com/cvmlp/vqa/mscoco/vqa/v2_Questions_Test_mscoco.zip"

# VQA Input Images (COCO)
# !gdown https://drive.google.com/uc?id=1-7wzyJhs5ZaHLmHwqjR2-OLS4EeGyVih

######################################################################

# !unzip $ANNOTATIONS_DIR/v2_Annotations_Train_mscoco.zip -d $ANNOTATIONS_DIR
# !unzip $ANNOTATIONS_DIR/v2_Annotations_Val_mscoco.zip -d $ANNOTATIONS_DIR

# !rm $ANNOTATIONS_DIR/v2_Annotations_Train_mscoco.zip
# !rm $ANNOTATIONS_DIR/v2_Annotations_Val_mscoco.zip

# !unzip $QUESTIONS_DIR/v2_Questions_Train_mscoco.zip -d $QUESTIONS_DIR
# !unzip $QUESTIONS_DIR/v2_Questions_Val_mscoco.zip -d $QUESTIONS_DIR
# !unzip $QUESTIONS_DIR/v2_Questions_Test_mscoco.zip -d $QUESTIONS_DIR

# !rm $QUESTIONS_DIR/v2_Questions_Train_mscoco.zip
# !rm $QUESTIONS_DIR/v2_Questions_Val_mscoco.zip
# !rm $QUESTIONS_DIR/v2_Questions_Test_mscoco.zip

# !unzip total.zip
# !mv /content/content/datasets/ResizedImages /content/datasets/Images/Resized_Images
import shutil
shutil.rmtree('/content/content')
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000446909.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000409331.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000077473.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000156370.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000045976.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000005184.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000261888.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000326308.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000472399.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000459265.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000020177.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000300725.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000174904.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000428712.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000551685.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000078915.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000255784.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000157756.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000271471.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000294832.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000256973.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000527440.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000223766.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000521088.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000308907.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000078023.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000121519.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000108761.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000506874.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000580418.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000558457.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000330536.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000177811.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000385139.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000352744.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000432843.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000382696.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000424268.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000527783.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000536343.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000411330.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000359442.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000003849.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000259422.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000545155.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000126345.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000538163.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000252269.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000374593.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000138573.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000348186.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000334034.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000296222.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000053434.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000516601.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000121089.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000272111.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000014282.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000245667.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000107094.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000267343.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000281924.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000164856.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000206838.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000404257.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000341603.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000528269.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000330098.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000571738.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000444672.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000294162.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000499397.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000104494.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000485236.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000213951.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000008190.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000390283.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000465069.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000033683.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000038355.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000313214.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000213375.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000407298.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000301641.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000179584.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000494393.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000330741.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000524611.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000061268.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000097967.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000049883.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000229134.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000544278.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000219524.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000568238.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000526459.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000071549.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000261186.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000058335.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000274708.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000260382.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000152333.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000012741.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000536366.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000234607.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000014892.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000525118.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000442306.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000060700.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000063934.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000386803.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000091716.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000397719.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000473199.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000418625.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000023294.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000069213.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000568115.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000340451.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000469134.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000005860.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000142454.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000531816.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000145439.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000096427.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000310200.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000239252.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000358090.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000435187.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000232865.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000160772.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000503399.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000148549.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000065170.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000205720.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000573791.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000092648.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000478528.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000381968.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000070294.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000280911.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000092801.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000454956.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000122300.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000517445.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000559483.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000483897.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000400728.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000316237.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000322944.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000485288.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000242095.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000221232.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000282808.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000295270.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000459400.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000579036.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000175718.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000536183.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000057150.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000488349.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000080895.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000175785.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000361972.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000466007.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000050306.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000520996.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000261155.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000090839.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000008589.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000260478.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000093201.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000357060.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000235788.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000021365.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000153994.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000083172.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000142127.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000449031.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000192154.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000061831.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000231379.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000445982.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000174989.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000522637.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000512223.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000389378.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000516775.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000241638.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000447779.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000409439.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000181796.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000181058.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000467511.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000345497.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000163600.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000522909.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000354061.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000250893.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000296634.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000073182.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000173211.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000105960.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000168883.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000335153.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000532833.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000318039.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000487575.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000211743.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000413235.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000207913.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000209747.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000560371.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000291305.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000068117.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000390689.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000429913.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000338256.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000276413.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000222075.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000424793.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000551849.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000362714.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000181739.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000160963.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000481398.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000424668.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000540544.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000003983.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000527828.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000324155.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000314914.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000496680.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000431691.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000525208.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000479939.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000255691.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000308276.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000430518.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000537671.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000558171.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000146150.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000341676.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000094566.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000542234.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000027578.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000408532.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000128699.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000401897.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000130732.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000569801.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000449073.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000321085.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000565941.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000417590.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000400048.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000089355.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000527961.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000045094.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000032944.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000241102.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000577783.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000045040.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000253455.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000232243.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000114634.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000316008.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000038336.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000513580.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000444324.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000279541.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000067995.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000444302.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000450620.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000377326.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000114352.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000530619.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000517306.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000556248.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000143483.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000172408.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000572899.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000252127.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000553761.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000283277.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000468954.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000059328.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000505826.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000053907.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000074446.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000304320.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000472678.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000136040.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000435179.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000215708.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000262003.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000392382.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000148588.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000364343.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000225670.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000031240.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000366711.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000462376.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000320664.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000186009.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000248276.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000041837.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000335610.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000255664.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000203239.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000478055.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000456127.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000533227.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000468784.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000042182.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000574141.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000016716.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000122994.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000422918.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000152214.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000336300.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000218091.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000058651.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000553721.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000421109.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000533032.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000319456.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000261426.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000141317.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000241517.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000441921.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000534817.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000572226.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000375219.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000139130.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000488977.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000467887.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000254104.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000257370.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000391255.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000395904.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000478858.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000408906.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000457907.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000173544.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000465275.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000504561.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000210032.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000432176.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000081079.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000578655.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000102159.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000488979.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000056669.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000309958.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000386589.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000034418.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000027932.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000010219.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000145383.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000485368.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000566249.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000135436.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000219393.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000336232.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000219965.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000328306.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000383413.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000439024.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000389503.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000348708.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000218204.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000423229.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000241551.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000394328.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000032779.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000290595.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000468162.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000342128.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000116413.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000121196.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000420826.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000290868.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000536891.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000145215.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000304819.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000011374.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000217312.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000424744.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000304828.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000324497.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000016439.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000173142.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000197350.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000501055.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000365121.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000523316.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000519338.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000048358.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000019763.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000188077.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000448426.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000457708.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000260166.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000151299.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000185768.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000465179.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000037882.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000044478.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000354533.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000169468.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000146190.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000183677.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000330500.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000196483.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000213421.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000431352.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000234785.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000166259.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000140826.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000094355.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000284292.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000053665.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000124390.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000195406.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000452274.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000021046.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000342025.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000017882.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000108923.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000511341.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000040497.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000055066.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000183967.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000196248.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000039790.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000027390.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000308974.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000267088.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000444126.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000550422.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000125815.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000366421.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000497604.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000041773.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000467142.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000394715.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000512729.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000287099.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000561578.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000269254.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000209007.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000176744.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000280761.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000565597.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000300867.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000092020.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000091756.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000366831.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000266348.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000525702.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000353518.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000434689.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000115830.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000116149.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000261796.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000014151.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000114158.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000041438.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000286556.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000358555.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000104015.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000194471.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000167159.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000192039.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000252201.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000338591.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000223740.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000073753.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000468129.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000263796.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000198397.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000281725.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000352234.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000431165.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000569001.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000491683.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000286018.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000467951.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000080300.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000045882.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000300032.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000226408.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000415196.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000217522.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000510657.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000135155.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000019667.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000255165.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000221291.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000177952.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000530731.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000388766.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000328452.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000205676.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000024104.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000055017.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000084004.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000346788.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000117014.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000004760.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000283963.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000389197.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000009378.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000551288.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000545826.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000114398.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000054517.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000309492.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000112867.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000145295.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000285421.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000315128.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000301107.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000573605.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000375461.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000090138.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000254653.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000384242.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000561054.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000141143.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000533239.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000031118.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000196185.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000032082.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000419119.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000368676.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000556240.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000404652.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000245642.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000462026.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000370899.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000544538.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000502766.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000149912.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000526133.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000052726.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000333365.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000297683.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000266124.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000006471.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000176563.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000317999.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000157617.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000518615.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000118134.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000565575.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000360762.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000257270.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000140651.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000215356.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000248238.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000571718.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000227709.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000311887.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000157093.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000307731.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000350107.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000137595.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000260036.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000515022.jpg
# ...
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000478320.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000105367.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000091643.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000536741.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000307166.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000135620.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000376706.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000566656.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000086483.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000249180.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000513524.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000109313.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000564816.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000100231.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000467151.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000256547.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000361527.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000403294.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000486104.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000363767.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000075775.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000526364.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000326593.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000355851.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000137911.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000345988.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000029059.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000201670.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000323507.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000252986.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000415393.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000164594.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000067213.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000062298.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000153510.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000457334.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000051272.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000009175.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000572620.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000579696.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000376342.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000000397.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000512463.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000135566.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000388795.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000156869.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000530652.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000202201.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000289995.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000058194.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000117690.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000362409.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000198247.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000388926.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000567693.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000333630.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000267664.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000223362.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000567205.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000022085.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000545734.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000230615.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000577619.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000386164.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000250790.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000478312.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000553097.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000321578.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000118069.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000373341.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000542611.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000166731.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000464312.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000452663.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000511906.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000432906.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000406053.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000543713.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000485865.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000331646.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000356949.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000460286.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000025551.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000406211.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000569703.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000369812.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000440779.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000376358.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000254869.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000513056.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000116434.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000122020.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000074629.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000489391.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000005804.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000051355.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000115412.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000147577.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000364980.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000419089.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000288769.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000410583.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000184659.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000495014.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000061564.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000489605.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000287874.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000176446.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000149268.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000097022.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000057460.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000387661.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000421673.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000046428.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000265464.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000329341.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000536034.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000430583.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000255928.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000114770.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000316648.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000044132.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000078113.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000050638.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000554466.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000539604.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000397109.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000487685.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000046440.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000368335.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000145209.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000481314.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000027476.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000524140.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000011115.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000090572.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000202843.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000121443.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000541924.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000554582.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000334244.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000169045.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000031596.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000487898.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000502663.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000375769.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000282427.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000220310.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000221932.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000568765.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000069584.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000424225.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000438999.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000003711.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000371004.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000056567.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000048564.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000028002.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000241668.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000303267.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000280819.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000256899.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000030383.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000267175.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000030548.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000201859.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000536294.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000163608.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000139567.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000401907.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000344881.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000466422.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000197915.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000220214.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000175597.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000145227.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000420052.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000027658.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000208793.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000573882.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000336257.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000329041.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000230600.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000081827.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000391642.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000048956.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000434148.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000465735.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000397857.jpg
#   inflating: content/datasets/ResizedImages/val2014/COCO_val2014_000000102947.jpg

# %% [markdown]
# ##Preprocess Input Data
# Preprocess input images, questions and answers.<br>
#   1. Resize Images
#   2. Make vocabs for questions and answers
#   3. Build VQA Inputs

# %% [markdown]
# ### Resize Images
# Resize the image from 640x480 -> 224x224.

# %%
'''Use the code below if you are resizing the images directly downladed from the official dataset.
def resize_image(image, size):
    """Resize an image to the given size."""
    return image.resize((size,size), Image.ANTIALIAS) # Option to prevent aliasing after resizing image.

def resize_images(input_dir, output_dir, size):
    """Resize the images in 'input_dir' and save into 'output_dir'."""
    for idir in os.scandir(input_dir):
        import pdb; pdb.set_trace()
        if not idir.is_dir():
            continue
        if not os.path.exists(output_dir+'/'+idir.name):
            os.makedirs(output_dir+'/'+idir.name)
        images = os.listdir(idir.path)
        n_images = len(images)
        for iimage, image in tqdm(enumerate(images)):
            if iimage >= 1000:
              break
            try:
                with open(os.path.join(idir.path, image), 'r+b') as f:
                    with Image.open(f) as img:
                        img = resize_image(img, size)
                        img.save(os.path.join(output_dir+'/'+idir.name, image), img.format)
                        original_img_path = os.path.join(idir.path,image)
            except(IOError, SyntaxError) as e:
                pass
            if (iimage+1) % 1000 == 0:
                print("[{}/{}] Resized the images and saved into '{}'."
                      .format(iimage+1, n_images, output_dir+'/'+idir.name))

input_dir = "./datasets/Images"
output_dir = "./datasets/ResizedImages"
img_size = 224

resize_images(input_dir,output_dir,img_size) # Resize Images'''

# %% [markdown]
# ### Make Vocabs for Questions and answers.
# Make a dictionary for questions and answers and save them into a txt file.

# %% [markdown]
# ## 1. Build the dictionary for questions.
# After running the code, the words in the dictionary can be observed in the vocab_questions.txt.

# %%
def make_vocab_questions(input_dir):
    """Make dictionary for questions and save them into text file."""
    vocab_set = set()
    SENTENCE_SPLIT_REGEX = re.compile(r'(\W+)')
    question_length = []
    datasets = os.listdir(input_dir)
    print(datasets)
    for dataset in datasets:
        if 'json' in dataset:
          with open(input_dir+'/'+dataset) as f:
              questions = json.load(f)['questions']
          set_question_length = [None]*len(questions)
          for iquestion, question in enumerate(questions):
              words = SENTENCE_SPLIT_REGEX.split(question['question'].lower())
              words = [w.strip() for w in words if len(w.strip()) > 0]
              vocab_set.update(words)
              set_question_length[iquestion] = len(words)
          question_length += set_question_length

    vocab_list = list(vocab_set)
    vocab_list.sort()
    vocab_list.insert(0, '<pad>')
    vocab_list.insert(1, '<unk>')

    with open('./datasets/vocab_questions.txt', 'w') as f:
        f.writelines([w+'\n' for w in vocab_list])

    print('Make vocabulary for questions')
    print('The number of total words of questions: %d' % len(vocab_set))
    print('Maximum length of question: %d' % np.max(question_length))

input_dir = "./datasets/"
make_vocab_questions(input_dir+'Questions')
# Out:
# ['v2_OpenEnded_mscoco_test2015_questions.json', 'v2_OpenEnded_mscoco_test-dev2015_questions.json', 'v2_OpenEnded_mscoco_train2014_questions.json', 'v2_OpenEnded_mscoco_val2014_questions.json']
# Make vocabulary for questions
# The number of total words of questions: 17854
# Maximum length of question: 26

# %% [markdown]
# ## 2. Build the dictionary for answers.
# Note that the number of words for the answers are cut to n_answers.<br>
# After running the code, the words in the dictionary can be observed in the vocab_answers.txt.

# %%
def make_vocab_answers(input_dir, n_answers):
    """Make dictionary for top n answers and save them into text file."""
    answers = defaultdict(lambda: 0)
    datasets = os.listdir(input_dir)
    for dataset in datasets:
      if 'json' in dataset:
          with open(input_dir+'/'+dataset) as f:
              annotations = json.load(f)['annotations']
          for annotation in annotations:
              for answer in annotation['answers']:
                  word = answer['answer']
                  if re.search(r"[^\w\s]", word):
                      continue
                  answers[word] += 1

    answers = sorted(answers, key=answers.get, reverse=True)
    assert('<unk>' not in answers)
    top_answers = ['<unk>'] + answers[:n_answers-1] # '-1' is due to '<unk>'. We restrict the number of words to n_answers.

    with open('./datasets/vocab_answers.txt', 'w') as f:
        f.writelines([w+'\n' for w in top_answers])

    print('Make vocabulary for answers')
    print('The number of total words of answers: %d' % len(answers))
    print('Keep top %d answers into vocab' % n_answers)

input_dir = "./datasets/"
n_answers = 1000

make_vocab_answers(input_dir+'Annotations',n_answers)
# Out:
# Make vocabulary for answers
# The number of total words of answers: 181102
# Keep top 1000 answers into vocab

# %% [markdown]
# ### Build VQA Inputs.

# %% [markdown]
# Define functions and classes that helps building inputs easier.

# %%
SENTENCE_SPLIT_REGEX = re.compile(r'(\W+)')


def tokenize(sentence):
    '''Question 1'''
    '''Use the SENTENCE_SPLIT_REGEX to tokenize the input sentence'''
    tokens =
    tokens =
    return tokens


def load_str_list(fname):
    with open(fname) as f:
        lines = f.readlines()
    lines = [l.strip() for l in lines]
    return lines
# Out:
#   File "/tmp/ipython-input-1405578578.py", line 7
#     tokens =
#             ^
# SyntaxError: invalid syntax

# %%
input = 'The world is changing.'
print(input)
print(tokenize(input))

# %% [markdown]
# ## Question 2 & 3
# ### Q2. Define the __init__ function of the class VocabDict that takes a vocab_file as input and then translates the word to index and index to word.
#
# ### The vocab_file is the .txt file that was the output of the functions make_vocab_questions, make_vocab_answers. Try giving them as input to fill in the blanks.
#
# ### Q3. Define the tokenize_and_index function.

# %%
class VocabDict:

    def __init__(self, vocab_file):
        self.word_list = load_str_list(vocab_file)
        '''Question 2'''
        '''Fill in the blanks below'''

        self.word2idx_dict =
        self.vocab_size =
        self.unk2idx =

    def idx2word(self, n_w):

        return self.word_list[n_w]

    def word2idx(self, w):
        if w in self.word2idx_dict:
            return self.word2idx_dict[w]
        elif self.unk2idx is not None:
            return self.unk2idx
        else:
            raise ValueError('word %s not in dictionary (while dictionary does not contain <unk>)' % w)

    def tokenize_and_index(self, sentence):
      '''Question 3'''
      '''This function takes a sentence as input and returns the indices of the tokenized words.
         Use the tokenize function you implemented above.'''

      inds =

      return inds

# %%
answer_vocab = VocabDict('./datasets/vocab_answers.txt')

# %%
answer_vocab.word2idx_dict['corn']
answer_vocab.unk2idx

# %% [markdown]
# ## Understanding the VocabDict class.
# ### Try playing with the VocabDict class with the text files from make_vocab_questions, make_vocab_answers.
#
# ### Try finding a sentence with all known vocabulary in the dictionary.

# %%
question_dict = VocabDict('./datasets/vocab_questions.txt')
answer_dict = VocabDict('./datasets/vocab_answers.txt')

answer_dict.tokenize_and_index('Yes No')

# %%
def extract_answers(q_answers, valid_answer_set):
    all_answers = [answer["answer"] for answer in q_answers]
    valid_answers = [a for a in all_answers if a in valid_answer_set]
    return all_answers, valid_answers


def vqa_processing(image_dir, annotation_file, question_file, valid_answer_set, image_set):
    print('building vqa %s dataset' % image_set)
    if image_set in ['train2014', 'val2014']:
        load_answer = True
        with open(annotation_file % image_set) as f:
            annotations = json.load(f)['annotations']
            qid2ann_dict = {ann['question_id']: ann for ann in annotations}
    else:
        load_answer = False
    with open(question_file % image_set) as f:
        questions = json.load(f)['questions']
    coco_set_name = image_set.replace('-dev', '')
    abs_image_dir = os.path.abspath(image_dir % coco_set_name)
    image_name_template = 'COCO_'+coco_set_name+'_%012d'
    dataset = [None]*len(questions)

    unk_ans_count = 0
    for n_q, q in enumerate(questions):
        if (n_q+1) % 10000 == 0:
            print('processing %d / %d' % (n_q+1, len(questions)))
        image_id = q['image_id']
        question_id = q['question_id']
        image_name = image_name_template % image_id
        image_path = os.path.join(abs_image_dir, image_name+'.jpg')
        question_str = q['question']
        question_tokens = tokenize(question_str)

        iminfo = dict(image_name=image_name,
                      image_path=image_path,
                      question_id=question_id,
                      question_str=question_str,
                      question_tokens=question_tokens)

        if load_answer:
            ann = qid2ann_dict[question_id]
            all_answers, valid_answers = extract_answers(ann['answers'], valid_answer_set)
            if len(valid_answers) == 0:
                valid_answers = ['<unk>']
                unk_ans_count += 1
            iminfo['all_answers'] = all_answers
            iminfo['valid_answers'] = valid_answers

        dataset[n_q] = iminfo
    print('total %d out of %d answers are <unk>' % (unk_ans_count, len(questions)))
    return dataset

#############################################################################################################
input_dir = "./datasets/"
output_dir = "./datasets/"

image_dir = input_dir+'/Images/Resized_Images/%s/'
annotation_file = input_dir+'/Annotations/v2_mscoco_%s_annotations.json'
question_file = input_dir+'/Questions/v2_OpenEnded_mscoco_%s_questions.json'

vocab_answer_file = output_dir+'/vocab_answers.txt'
answer_dict = VocabDict(vocab_answer_file)
valid_answer_set = set(answer_dict.word_list)

train = vqa_processing(image_dir, annotation_file, question_file, valid_answer_set, 'train2014')
valid = vqa_processing(image_dir, annotation_file, question_file, valid_answer_set, 'val2014')
test = vqa_processing(image_dir, annotation_file, question_file, valid_answer_set, 'test2015')
test_dev = vqa_processing(image_dir, annotation_file, question_file, valid_answer_set, 'test-dev2015')

np.save(output_dir+'/train.npy', np.array(train))
np.save(output_dir+'/valid.npy', np.array(valid))
np.save(output_dir+'/train_valid.npy', np.array(train+valid))
np.save(output_dir+'/test.npy', np.array(test))
np.save(output_dir+'/test-dev.npy', np.array(test_dev))

# %% [markdown]
# ## Try testing the train, validation and test dataset

# %%
train[0]

# %% [markdown]
# #DataLoader

# %%
class VqaDataset(data.Dataset):

    def __init__(self, input_dir, input_vqa, max_qst_length=30, max_num_ans=10, transform=None):
        self.input_dir = input_dir
        self.vqa = np.load(input_dir+'/'+input_vqa,allow_pickle=True)
        self.qst_vocab = VocabDict(input_dir+'/vocab_questions.txt')
        self.ans_vocab = VocabDict(input_dir+'/vocab_answers.txt')
        self.max_qst_length = max_qst_length
        self.max_num_ans = max_num_ans
        self.load_ans = ('valid_answers' in self.vqa[0]) and (self.vqa[0]['valid_answers'] is not None)
        self.transform = transform

    def __getitem__(self, idx):

        vqa = self.vqa
        qst_vocab = self.qst_vocab
        ans_vocab = self.ans_vocab
        max_qst_length = self.max_qst_length
        max_num_ans = self.max_num_ans
        transform = self.transform
        load_ans = self.load_ans

        image = vqa[idx]['image_path']
        image = Image.open(image).convert('RGB')
        qst2idc = np.array([qst_vocab.word2idx('<pad>')] * max_qst_length)  # padded with '<pad>' in 'ans_vocab'
        qst2idc[:len(vqa[idx]['question_tokens'])] = [qst_vocab.word2idx(w) for w in vqa[idx]['question_tokens']]
        sample = {'image': image, 'question': qst2idc}

        if load_ans:
            ans2idc = [ans_vocab.word2idx(w) for w in vqa[idx]['valid_answers']]
            ans2idx = np.random.choice(ans2idc)
            sample['answer_label'] = ans2idx         # for training

            mul2idc = list([-1] * max_num_ans)       # padded with -1 (no meaning) not used in 'ans_vocab'
            mul2idc[:len(ans2idc)] = ans2idc         # our model should not predict -1
            sample['answer_multi_choice'] = mul2idc  # for evaluation metric of 'multiple choice'

        if transform:
            sample['image'] = transform(sample['image'])

        return sample

    def __len__(self):

        return len(self.vqa)


def get_loader(input_dir, input_vqa_train, input_vqa_valid, max_qst_length, max_num_ans, batch_size, num_workers):

    transform = {
        phase: transforms.Compose([transforms.ToTensor(),
                                   transforms.Normalize((0.485, 0.456, 0.406),
                                                        (0.229, 0.224, 0.225))])
        for phase in ['train', 'valid']}

    vqa_dataset = {
        'train': VqaDataset(
            input_dir=input_dir,
            input_vqa=input_vqa_train,
            max_qst_length=max_qst_length,
            max_num_ans=max_num_ans,
            transform=transform['train']),
        'valid': VqaDataset(
            input_dir=input_dir,
            input_vqa=input_vqa_valid,
            max_qst_length=max_qst_length,
            max_num_ans=max_num_ans,
            transform=transform['valid'])}

    data_loader = {
        phase: torch.utils.data.DataLoader(
            dataset=vqa_dataset[phase],
            batch_size=batch_size,
            shuffle=True,
            num_workers=num_workers)
        for phase in ['train', 'valid']}

    return data_loader

# %% [markdown]
# ## Model
# Our model is consisted of 3 big parts.
# 1. Image Encoder : Returns the image features.
# 2. Question Encoder : Encodes the questions with the defined dictionary.
# 3. FC Layer: Estimate the class of the combined features from both encoders.

# %% [markdown]
# ### 1. Image Encoder

# %%
model = models.vgg19(pretrained=True)
print(model.classifier[-1].in_features)

# %%
print(*list(model.classifier.children()))

# %%
class ImgEncoder(nn.Module):

    def __init__(self, embed_size):
        """(1) Load the pretrained model as you want.
               cf) one needs to check structure of model using 'print(model)'
                   to remove last fc layer from the model.
           (2) Replace final fc layer (score values from the ImageNet)
               with new fc layer (image feature).
           (3) Normalize feature vector.
        """
        super(ImgEncoder, self).__init__()
        model = models.vgg19(pretrained=True)
        '''Question 4'''
        '''Fill in the blanks so that it matches (1) and (2) in the function description.'''
        in_features =  # input size of feature vector
        model.classifier =  # remove last fc layer

        self.model =                             # loaded model without last fc layer
        self.fc =     # feature vector of image

    def forward(self, image):
        """Extract feature vector from image vector.
        """
        with torch.no_grad():
            img_feature = self.model(image)                  # [batch_size, vgg16(19)_fc=4096]
        img_feature = self.fc(img_feature)                   # [batch_size, embed_size]

        '''Question 5'''
        '''L2 Normalize the img_features from self.fc()'''
        l2_norm =
        img_feature =               # l2-normalized feature vector

        return img_feature

# %%
x = torch.rand(20,3,224,224)
test = ImgEncoder(1024)
out = test(x)
print(out.shape)

# %% [markdown]
# ### 2. Question Encoder

# %%
class QstEncoder(nn.Module):

    def __init__(self, qst_vocab_size, word_embed_size, embed_size, num_layers, hidden_size):

        super(QstEncoder, self).__init__()
        '''Question 6'''
        '''Define the following functions using the nn library.'''
        '''Please look at the documents of the functions nn.Embedding, nn.Tanh, nn.LSTM, nn.Linear to match the dimensions.'''
        '''word2vec : A learnable layer that takes the vocabulary id and return a embedding vector '''

        self.word2vec = nn.Embedding(qst_vocab_size)
        self.tanh = nn.Tanh()
        self.lstm = nn.LSTM()
        self.fc = nn.Linear()     # 2 for hidden and cell states

    def forward(self, question):

        qst_vec = self.word2vec(question)                             # [batch_size, max_qst_length=30, word_embed_size=300]
        qst_vec = self.tanh(qst_vec)
        qst_vec = qst_vec.transpose(0, 1)                             # [max_qst_length=30, batch_size, word_embed_size=300]
        _, (hidden, cell) = self.lstm(qst_vec)                        # [num_layers=2, batch_size, hidden_size=512]
        qst_feature = torch.cat((hidden, cell), 2)                    # [num_layers=2, batch_size, 2*hidden_size=1024]
        qst_feature = qst_feature.transpose(0, 1)                     # [batch_size, num_layers=2, 2*hidden_size=1024]
        qst_feature = qst_feature.reshape(qst_feature.size()[0], -1)  # [batch_size, 2*num_layers*hidden_size=2048]
        qst_feature = self.tanh(qst_feature)
        qst_feature = self.fc(qst_feature)                            # [batch_size, embed_size]

        return qst_feature

# %% [markdown]
# ## VQA Model

# %%
class VqaModel(nn.Module):

    def __init__(self, embed_size, qst_vocab_size, ans_vocab_size, word_embed_size, num_layers, hidden_size):

        super(VqaModel, self).__init__()
        self.img_encoder = ImgEncoder(embed_size)
        self.qst_encoder = QstEncoder(qst_vocab_size, word_embed_size, embed_size, num_layers, hidden_size)
        self.tanh = nn.Tanh()
        self.dropout = nn.Dropout(0.5)
        self.fc1 = nn.Linear(embed_size, ans_vocab_size)
        self.fc2 = nn.Linear(ans_vocab_size, ans_vocab_size)

    def forward(self, img, qst):

        img_feature = self.img_encoder(img)                     # [batch_size, embed_size]
        qst_feature = self.qst_encoder(qst)                     # [batch_size, embed_size]
        combined_feature = torch.mul(img_feature, qst_feature)  # [batch_size, embed_size]
        combined_feature = self.tanh(combined_feature)
        combined_feature = self.dropout(combined_feature)
        combined_feature = self.fc1(combined_feature)           # [batch_size, ans_vocab_size=1000]
        combined_feature = self.tanh(combined_feature)
        combined_feature = self.dropout(combined_feature)
        combined_feature = self.fc2(combined_feature)           # [batch_size, ans_vocab_size=1000]

        return combined_feature

# %% [markdown]
# #Start Training

# %%
args = easydict.EasyDict()

## Parameters for training
args.input_dir = './datasets' # Input Directory for VQA
args.log_dir = './logs' # Directory for logs
args.model_dir = './models' # Directory for saved models
args.max_qst_length = 30 # Maximum length of quesiton.
args.max_num_ans = 10 # Maximum number of answers.
args.embed_size = 1024 # Embedding size of feature vectors for both image and question.
args.word_embed_size = 300 # Embedding size of word used for the input in the LSTM.
args.num_layers = 2 # Number os Layers of the RNN(LSTM).
args.hidden_size = 512 # Hidden size in the LSTM.
args.learning_rate = 0.001 # Learning rate for training.
args.step_size = 10 # Period of Learning Rate Decay.
args.gamma = 0.1 # Multiplicative factor of learning rate decay.
args.num_epochs = 1 # Number of epochs.
args.batch_size = 256 # Batch size.
args.num_workers = 0 # Number of processes working on cpu.
args.save_step = 1 # Save step of model.

print(args)

# %%
'''Question 7'''
'''Define the loss function'''
def custom_ce(pred,label):
  return

# %%
import torch
import torch.nn as nn
x = torch.rand((20,10))
y = torch.randint(low=0,high=9,size=(20,)).to(torch.int64)
real = nn.CrossEntropyLoss()
print(custom_ce(x,y))
print(real(x,y))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def train(args):

    os.makedirs(args.log_dir, exist_ok=True)
    os.makedirs(args.model_dir, exist_ok=True)

    data_loader = get_loader(
        input_dir=args.input_dir,
        input_vqa_train='train.npy',
        input_vqa_valid='valid.npy',
        max_qst_length=args.max_qst_length,
        max_num_ans=args.max_num_ans,
        batch_size=args.batch_size,
        num_workers=args.num_workers)

    qst_vocab_size = data_loader['train'].dataset.qst_vocab.vocab_size
    ans_vocab_size = data_loader['train'].dataset.ans_vocab.vocab_size
    ans_unk_idx = data_loader['train'].dataset.ans_vocab.unk2idx

    model = VqaModel(
        embed_size=args.embed_size,
        qst_vocab_size=qst_vocab_size,
        ans_vocab_size=ans_vocab_size,
        word_embed_size=args.word_embed_size,
        num_layers=args.num_layers,
        hidden_size=args.hidden_size).to(device)

    criterion = custom_ce

    params = list(model.img_encoder.fc.parameters()) \
        + list(model.qst_encoder.parameters()) \
        + list(model.fc1.parameters()) \
        + list(model.fc2.parameters())

    optimizer = optim.Adam(params, lr=args.learning_rate)
    scheduler = lr_scheduler.StepLR(optimizer, step_size=args.step_size, gamma=args.gamma)
    phase = 'train'

    for epoch in range(args.num_epochs):
      running_loss = 0.0
      running_corr_exp1 = 0
      batch_step_size = len(data_loader[phase].dataset) / args.batch_size

      model.train()

      for batch_idx, batch_sample in enumerate(data_loader[phase]):
        image = batch_sample['image'].to(device)
        question = batch_sample['question'].to(device)
        label = batch_sample['answer_label'].to(device)
        multi_choice = batch_sample['answer_multi_choice']  # not tensor, list.

        optimizer.zero_grad()
        with torch.set_grad_enabled(phase == 'train'):
            output = model(image, question)      # [batch_size, ans_vocab_size=1000]
            _, pred_exp1 = torch.max(output, 1)  # [batch_size]
            loss = criterion(output, label)

            loss.backward()
            optimizer.step()
            scheduler.step()

        # Evaluation metric of 'multiple choice'
        # Exp1: our model prediction to '<unk>' IS accepted as the answer.
        # Exp2: our model prediction to '<unk>' is NOT accepted as the answer.
        running_loss += loss.item()
        running_corr_exp1 += torch.stack([(ans == pred_exp1.cpu()) for ans in multi_choice]).any(dim=0).sum()

        # Print the average loss in a mini-batch.
        if batch_idx % 100 == 0:
            print('| {} SET | Epoch [{:02d}/{:02d}], Step [{:04d}/{:04d}], Loss: {:.4f}'
                  .format(phase.upper(), epoch+1, args.num_epochs, batch_idx, int(batch_step_size), loss.item()))
        # Save the model check points.
        if (batch_idx) == 500:
            torch.save({'epoch': epoch+1, 'state_dict': model.state_dict()},
                        os.path.join(args.model_dir, 'model-epoch-{:02d}.ckpt'.format(epoch+1)))
            break

      if (epoch + 1) % args.save_step == 0:
        torch.save({'epoch': epoch+1, 'state_dict': model.state_dict()},
                        os.path.join(args.model_dir, 'model-epoch-{:02d}.ckpt'.format(epoch+1)))

# %%
train(args)

# %% [markdown]
# # Evaluate our model with the test data.

# %%
import gc; gc.collect()
torch.cuda.empty_cache()

# %%
# !gdown https://drive.google.com/uc?id=17C8uZTm6WHW0c2q4pi5v-gHzqbegA6LV
# !mv model-epoch-25.ckpt models/

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
phase = 'valid'
answer_dict = VocabDict('./datasets/vocab_answers.txt')
question_dict = VocabDict('./datasets/vocab_questions.txt')
tensor2img = transforms.ToPILImage()

def eval(args):

    os.makedirs(args.log_dir, exist_ok=True)
    os.makedirs(args.model_dir, exist_ok=True)

    data_loader = get_loader(
        input_dir=args.input_dir,
        input_vqa_train='train.npy',
        input_vqa_valid='valid.npy',
        max_qst_length=args.max_qst_length,
        max_num_ans=args.max_num_ans,
        batch_size=args.batch_size,
        num_workers=args.num_workers)

    qst_vocab_size = data_loader['valid'].dataset.qst_vocab.vocab_size
    ans_vocab_size = data_loader['valid'].dataset.ans_vocab.vocab_size
    ans_unk_idx = data_loader['valid'].dataset.ans_vocab.unk2idx

    model = VqaModel(
        embed_size=args.embed_size,
        qst_vocab_size=qst_vocab_size,
        ans_vocab_size=ans_vocab_size,
        word_embed_size=args.word_embed_size,
        num_layers=args.num_layers,
        hidden_size=args.hidden_size)

    # path = './models/model-epoch-01.ckpt'
    path = './models/model-epoch-25.ckpt'
    model.load_state_dict(torch.load(path),strict=False)
    model.to(device)

    model.eval()
    for batch_idx, batch_sample in enumerate(data_loader[phase]):
      image = batch_sample['image'].to(device)
      question = batch_sample['question'].to(device)
      label = batch_sample['answer_label'].to(device)
      multi_choice = batch_sample['answer_multi_choice']  # not tensor, list.

      output = model(image,question)
      _, pred = torch.max(output,0)

      for i in range(args.batch_size):
        import pdb; pdb.set_trace()
        trans_img = image[i].transpose(0,1).transpose(1,2).cpu()
        q = question[i]
        q_ques = []
        plt.imshow(trans_img)
        for q_q in q.tolist():
          q_ques.append(question_dict.idx2word(q_q))
        l = label[i]
        p = pred[i]
        print("The question is : ")
        print(q_ques)
        print("The answer is : " + answer_dict.idx2word(l))
        print("The output of our model is :" + answer_dict.idx2word(p))

# %%
eval(args)
